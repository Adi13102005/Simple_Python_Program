# %% [markdown]
# <a href="https://colab.research.google.com/github/Adi13102005/Simple_Python_Program/blob/main/Practical2(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
*DSL_Experiment_02*

# %% [markdown]
# 1. Breadth-First Search (BFS) and Depth-First Search (DFS)

# %%
# Define a simple graph using an adjacency list
graph = {
    'A': ['B', 'C'],
    'B': ['A', 'D', 'E'],
    'C': ['A', 'F'],
    'D': ['B'],
    'E': ['B', 'F'],
    'F': ['C', 'E']
}

print("Graph representation:", graph)

from collections import deque

def bfs(graph, start_node):
    visited = set()
    queue = deque([start_node])
    traversal_order = []

    visited.add(start_node)

    while queue:
        node = queue.popleft()
        traversal_order.append(node)

        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

    return traversal_order

print("BFS Traversal starting from 'A':", bfs(graph, 'A'))
# Out:
# Graph representation: {'A': ['B', 'C'], 'B': ['A', 'D', 'E'], 'C': ['A', 'F'], 'D': ['B'], 'E': ['B', 'F'], 'F': ['C', 'E']}
# BFS Traversal starting from 'A': ['A', 'B', 'C', 'D', 'E', 'F']

# %%
def dfs(graph, start_node):
    visited = set()
    stack = [start_node]
    traversal_order = []

    while stack:
        node = stack.pop()
        if node not in visited:
            visited.add(node)
            traversal_order.append(node)
            # Push neighbors onto the stack in reverse order to explore in alphabetical order (or desired order)
            for neighbor in sorted(graph[node], reverse=True):
                if neighbor not in visited:
                    stack.append(neighbor)

    return traversal_order

print("DFS Traversal starting from 'A':", dfs(graph, 'A'))
# Out:
# DFS Traversal starting from 'A': ['A', 'B', 'D', 'E', 'F', 'C']
